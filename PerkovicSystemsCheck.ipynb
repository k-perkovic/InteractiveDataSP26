# %% [markdown]
# ## Kaitlyn Perkovic
# ### Emat 62110
# ##### 01/15/2026

# %%
my_name = "Kaitlyn"
my_name

def give_name():
    print(my_name)

give_name()
# Out:
# Kaitlyn

# %%
def return_name():
    return my_name

new_name = return_name()
new_name
# Out:
# 'Kaitlyn'
