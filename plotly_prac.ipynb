# %%
import plotly.express as px
import pandas as pd
# importing plotly.express to create the graphs
# importing pandas to read the data in the csv

# %%
food = pd.read_csv('daily_food_delivery_orders.csv')
food.head(15)
# reading the csv using pandas and giving it a variable of food. showing the first 15 elements (out of 2k+) in this dataset.
# Out:
#     order_id  order_date  customer_age restaurant_type  order_value  \
# 0          1  2024-11-05            62          Indian       497.51
# 1          2  2024-08-20            35          Bakery       232.32
# 2          3  2024-02-28            34         Italian       540.82
# 3          4  2024-05-26            65            Cafe      1197.99
# 4          5  2024-09-21            40          Indian       947.03
# 5          6  2024-03-16            51         Italian       835.75
# 6          7  2024-11-20            52            Cafe       771.83
# 7          8  2024-11-24            52         Chinese       926.20
# 8          9  2024-07-23            38          Bakery       548.11
# 9         10  2024-07-01            24       Fast Food       177.18
# 10        11  2024-09-16            27            Cafe       806.68
# 11        12  2024-08-27            61          Bakery      1193.33
# 12        13  2024-01-09            31         Chinese       758.14
# ...

# %%
df.sort_values(by='order_date', inplace=True)
df
# sorting the data by order date using pandas to create the first figure | reference: https://stackoverflow.com/questions/41433765/pandas-dataframe-sort-by-date
# Out:
#     order_id  order_date  customer_age restaurant_type  order_value  \
# 12        13  2024-01-09            31         Chinese       758.14
# 2          3  2024-02-28            34         Italian       540.82
# 5          6  2024-03-16            51         Italian       835.75
# 3          4  2024-05-26            65            Cafe      1197.99
# 9         10  2024-07-01            24       Fast Food       177.18
# 8          9  2024-07-23            38          Bakery       548.11
# 1          2  2024-08-20            35          Bakery       232.32
# 14        15  2024-08-21            62         Chinese       810.18
# 11        12  2024-08-27            61          Bakery      1193.33
# 13        14  2024-09-02            47            Cafe       937.07
# 10        11  2024-09-16            27            Cafe       806.68
# 4          5  2024-09-21            40          Indian       947.03
# 0          1  2024-11-05            62          Indian       497.51
# ...

# %%
fig = px.line(df, x='order_date', y='order_value')
fig.show()
# using plotly express, i used the order data, with the x axis containing the order date and the y axis containing the order value | reference: plotly.com/python/line-charts/

# %%
fig1 = px.bar(df, x='restaurant_type', y='payment_method', color='order_status', barmode='group')
fig1.show()
# using plotly express, i used the order data, with the x axis containing the restaurant type and the y axis containing the payment method with colors representing the order status. | reference: plotly.com/python/bar-charts/

# %%
fig2 = px.pie(df, values='customer_age', names='payment_method')
fig2.show()
#using plotly express, i created a pie chart using the first 15 elements of the data. i measured the customer age (which resulted)
# in adding all of the customer ages and dividing to find the average, while making the payment method the names.
# reference: plotly.com/python/pie-charts/

# %%
fig = dict({
    "data": [{"type": "bar",
              "x": [1, 2, 3],
              "y": [1, 3, 2]}],
    "layout": {"title": {"text": "A Figure Specified By Python Dictionary"}}
})

# To display the figure defined by this dict, use the low-level plotly.io.show function
import plotly.io as pio

pio.show(fig)
