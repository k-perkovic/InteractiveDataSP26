# %% [markdown]
# # __Systems Check__
# ### Kaitlyn Perkovic
# ##### Interactive Data -  _EMAT 62110_

# %% [markdown]
# ## _What I Would Like To Get Out Of This Class:_
# 1. To understand how to present data, and how to do so to my __target audience__.
# 2. To be able to use my skills and abilities used in this class to present data that shows __change__ in subject areas of my interest.
# 3. To better my skills using __Visual Studio Code__ and __Python__

# %%
my_name = "Kaitlyn"
my_name
# Out:
# 'Kaitlyn'

# %%
my_name = "Kaitlyn"
my_name

def give_name():
    print(my_name)

give_name()
# Out:
# Kaitlyn

# %%
def return_name():
    return my_name

new_name = return_name()
new_name
# Out:
# 'Kaitlyn'

# %%
from IPython.display import Image

Image(url="cat.jpeg", width=200, height=300)
# https://www.geeksforgeeks.org/python/insert-image-in-a-jupyter-notebook/
# Out:
# <img src="cat.jpeg" width="200" height="300"/>

# %% [markdown]
# For now, above is a picture of my cat, Peanut!
